# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
# loading the dataset to a pandas DataFrame
creditcard = pd.read_csv('/content/creditcard.csv')

# %%
# first 5 rows of the dataset
creditcard.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62    0.0
# 1  0.125895 -0.008983  0.014724    2.69    0.0
# 2 -0.139097 -0.055353 -0.059752  378.66    0.0
# 3 -0.221929  0.062723  0.061458  123.50    0.0
# 4  0.502292  0.219422  0.215153   69.99    0.0
#
# [5 rows x 31 columns]

# %%
creditcard.tail()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 67429  52531 -0.668025  0.539737  0.161731 -1.071380  1.529141  3.819435
# 67430  52532 -0.679169  1.237672  1.602476 -0.007797 -0.228123 -1.095514
# 67431  52532 -0.102663  0.890146  1.178701 -0.062896  0.289073 -0.377077
# 67432  52532  0.797464 -0.947293  1.045822  0.263474 -1.194980  0.348919
# 67433  52534  1.210560  0.291028  0.273319  0.646091 -0.199608 -0.606096
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 67429 -0.685869  1.486179 -0.293208  ...  0.214492  0.282335  0.070720
# 67430  0.734340 -0.106748 -0.298766  ... -0.233214 -0.517932  0.020122
# 67431  0.753827  0.035692 -0.936965  ... -0.292659 -0.897627  0.275655
# 67432 -0.594826  0.268371  0.870239  ... -0.039739 -0.211713 -0.023972
# 67433  0.000425 -0.056976  0.051479  ...       NaN       NaN       NaN
#
#             V24       V25       V26       V27       V28  Amount  Class
# 67429  1.022712 -0.505535  0.253658  0.017185  0.105271   49.97    0.0
# 67430  0.702798 -0.170477  0.054315  0.380961  0.183103    7.13    0.0
# 67431  0.190260 -0.804461 -0.240939  0.028038  0.029944    9.50    0.0
# 67432  0.313647 -0.045046  0.924183 -0.049685  0.031583  170.82    0.0
# 67433       NaN       NaN       NaN       NaN       NaN     NaN    NaN
#
# [5 rows x 31 columns]

# %%
# dataset informations
creditcard.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67434 entries, 0 to 67433
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    67434 non-null  int64
#  1   V1      67434 non-null  float64
#  2   V2      67434 non-null  float64
#  3   V3      67434 non-null  float64
#  4   V4      67434 non-null  float64
#  5   V5      67434 non-null  float64
#  6   V6      67434 non-null  float64
#  7   V7      67434 non-null  float64
#  8   V8      67434 non-null  float64
#  9   V9      67434 non-null  float64
#  10  V10     67434 non-null  float64
#  11  V11     67434 non-null  float64
#  12  V12     67434 non-null  float64
#  13  V13     67434 non-null  float64
#  14  V14     67434 non-null  float64
#  15  V15     67434 non-null  float64
#  16  V16     67434 non-null  float64
#  17  V17     67434 non-null  float64
#  18  V18     67434 non-null  float64
#  19  V19     67434 non-null  float64
#  20  V20     67434 non-null  float64
#  21  V21     67433 non-null  float64
#  22  V22     67433 non-null  float64
#  23  V23     67433 non-null  float64
#  24  V24     67433 non-null  float64
#  25  V25     67433 non-null  float64
#  26  V26     67433 non-null  float64
#  27  V27     67433 non-null  float64
#  28  V28     67433 non-null  float64
#  29  Amount  67433 non-null  float64
#  30  Class   67433 non-null  float64
# dtypes: float64(30), int64(1)
# memory usage: 15.9 MB

# %%
 # checking the number of missing values in each column
 creditcard.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       1
# V22       1
# V23       1
# V24       1
# V25       1
# V26       1
# V27       1
# V28       1
# Amount    1
# Class     1
# dtype: int64

# %%
# distribution of legit transactions
creditcard['Class'].value_counts()
# Out:
# Class
# 0.0    67264
# 1.0      169
# Name: count, dtype: int64

# %% [markdown]
# This Dataset is highly unbalanced

# %%
# seperating the data for analysis
legit = creditcard[creditcard.Class == 0]
fraud = creditcard[creditcard.Class == 1]

# %%
print(legit.shape)
print(fraud.shape)
# Out:
# (67264, 31)
# (169, 31)

# %%
# statistical measures of the data
legit.Amount.describe()
# Out:
# count    67264.000000
# mean        96.632489
# std        270.008302
# min          0.000000
# 25%          7.680000
# 50%         26.380000
# 75%         88.360000
# max      19656.530000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     169.000000
# mean       94.895680
# std       220.959331
# min         0.000000
# 25%         1.000000
# 50%         7.610000
# 75%        99.990000
# max      1809.680000
# Name: Amount, dtype: float64

# %%
# compare the values for both the tranasaction
creditcard.groupby("Class").mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0.0    33987.964275 -0.224397 -0.031225  0.709220  0.156146 -0.256028
# 1.0    29493.242604 -7.106029  5.115846 -9.566072  5.470948 -5.263861
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.107483 -0.096094  0.048974  0.038459  ...  0.046365 -0.030766
# 1.0   -2.172211 -7.412550  3.501007 -3.298551  ...  0.431494  0.850670
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.106221 -0.038280  0.005830  0.136332  0.020505  0.001370  0.003425
# 1.0   -0.212903 -0.255225 -0.075295  0.245601  0.107931  0.576249  0.041284
#
#           Amount
# Class
# 0.0    96.632489
# 1.0    94.895680
#
# [2 rows x 30 columns]

# %% [markdown]
# under-Sampling

# %% [markdown]
# Build a sample dataset containing similar distribution of normal tranasactions

# %% [markdown]
# Number of Fraudulent Transactions -->492

# %%
legit_sample = legit.sample(n=492)

# %% [markdown]
# concatenating two DataFrames

# %%
new_dataset = pd.concat([legit_sample, fraud], axis=0)

# %%
new_dataset.head()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 26268  33976  0.990182 -0.053769  0.263690  1.280483 -0.281139 -0.377423
# 45643  42436  1.258657  0.421016  0.325437  0.684259 -0.292529 -1.052786
# 50011  44304  1.118176 -0.113425  1.341694  1.211844 -1.128599 -0.133668
# 51705  45083  1.214251  0.321666  0.282478  0.641298 -0.167109 -0.598541
# 55544  47003 -2.645416 -0.650354  0.699938 -0.939544 -0.460305  0.793454
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 26268  0.164353 -0.065482  0.029121  ...  0.156275  0.280870 -0.166172
# 45643  0.145228 -0.253567 -0.100521  ... -0.278029 -0.757417  0.119613
# 50011 -0.745899  0.283339  0.707395  ...  0.038199  0.167271  0.031323
# 51705  0.021435 -0.076085 -0.000471  ... -0.258063 -0.699432  0.156970
# 55544 -0.619544  1.357572  0.462394  ... -0.066999 -0.498590 -0.116966
#
#             V24       V25       V26       V27       V28  Amount  Class
# 26268  0.085264  0.549844 -0.261117  0.012580  0.035939  108.00    0.0
# 45643  0.369393  0.246145  0.091553 -0.017156  0.032557    0.89    0.0
# 50011  0.489935  0.286082 -0.424303  0.057538  0.026498    1.18    0.0
# 51705  0.039196  0.150016  0.123524 -0.005230  0.027740    1.29    0.0
# 55544 -1.082198 -0.033793  0.866450 -0.005089 -0.272605  121.30    0.0
#
# [5 rows x 31 columns]

# %%
new_dataset.tail()
# Out:
#         Time         V1        V2         V3        V4        V5        V6  \
# 63421  50706  -8.461845  6.866198 -11.838269  4.194211 -6.923097 -3.221147
# 63634  50808  -9.169790  7.092197 -12.354037  4.243069 -7.176438 -3.386618
# 64329  51112  -9.848776  7.365546 -12.898538  4.273323 -7.611991 -3.427045
# 64411  51135 -10.527304  7.639745 -13.443115  4.303403 -8.048210 -3.466997
# 64460  51155 -11.205461  7.914633 -13.987752  4.333341 -8.484970 -3.506561
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 63421 -7.553497  6.015618 -2.466143  ...  0.918244 -0.715366  0.210747
# 63634 -8.058012  6.442909 -2.412987  ...  0.926157 -0.817706 -0.150434
# 64329 -8.350808  6.863604 -2.387567  ...  0.931958 -0.874467 -0.192639
# 64411 -8.643193  7.284105 -2.362097  ...  0.937416 -0.931178 -0.235697
# 64460 -8.935243  7.704449 -2.336584  ...  0.942593 -0.987848 -0.279446
#
#             V24       V25       V26       V27       V28  Amount  Class
# 63421 -0.060211  0.509535 -0.257284  1.170027  0.229301   99.99    1.0
# 63634 -0.039383  0.485640 -0.264325  1.159690  0.232758   99.99    1.0
# 64329 -0.035426  0.538665 -0.263934  1.134095  0.225973   99.99    1.0
# 64411 -0.031393  0.591558 -0.263516  1.108897  0.219021   99.99    1.0
# 64460 -0.027299  0.644344 -0.263078  1.084023  0.211933   99.99    1.0
#
# [5 rows x 31 columns]

# %%
new_dataset['Class'].value_counts()
# Out:
# Class
# 0.0    492
# 1.0    169
# Name: count, dtype: int64

# %%
new_dataset.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0.0    34499.540650 -0.223752 -0.028063  0.688527  0.184221 -0.255459
# 1.0    29493.242604 -7.106029  5.115846 -9.566072  5.470948 -5.263861
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.124307 -0.082304  0.100107  0.064316  ... -0.003213 -0.054547
# 1.0   -2.172211 -7.412550  3.501007 -3.298551  ...  0.431494  0.850670
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.094718 -0.016302  0.012712  0.151276  0.005924 -0.013040 -0.012813
# 1.0   -0.212903 -0.255225 -0.075295  0.245601  0.107931  0.576249  0.041284
#
#           Amount
# Class
# 0.0    91.720793
# 1.0    94.895680
#
# [2 rows x 30 columns]

# %% [markdown]
# splitting the data into Features & Targets

# %%
X = new_dataset.drop(columns='Class', axis=1)
Y = new_dataset['Class']

# %%
print(X)
# Out:
#         Time         V1        V2         V3        V4        V5        V6  \
# 26268  33976   0.990182 -0.053769   0.263690  1.280483 -0.281139 -0.377423
# 45643  42436   1.258657  0.421016   0.325437  0.684259 -0.292529 -1.052786
# 50011  44304   1.118176 -0.113425   1.341694  1.211844 -1.128599 -0.133668
# 51705  45083   1.214251  0.321666   0.282478  0.641298 -0.167109 -0.598541
# 55544  47003  -2.645416 -0.650354   0.699938 -0.939544 -0.460305  0.793454
# ...      ...        ...       ...        ...       ...       ...       ...
# 63421  50706  -8.461845  6.866198 -11.838269  4.194211 -6.923097 -3.221147
# 63634  50808  -9.169790  7.092197 -12.354037  4.243069 -7.176438 -3.386618
# 64329  51112  -9.848776  7.365546 -12.898538  4.273323 -7.611991 -3.427045
# 64411  51135 -10.527304  7.639745 -13.443115  4.303403 -8.048210 -3.466997
# 64460  51155 -11.205461  7.914633 -13.987752  4.333341 -8.484970 -3.506561
#
#              V7        V8        V9  ...       V20       V21       V22  \
# 26268  0.164353 -0.065482  0.029121  ...  0.013184  0.156275  0.280870
# 45643  0.145228 -0.253567 -0.100521  ... -0.026262 -0.278029 -0.757417
# 50011 -0.745899  0.283339  0.707395  ... -0.230671  0.038199  0.167271
# 51705  0.021435 -0.076085 -0.000471  ... -0.101115 -0.258063 -0.699432
# 55544 -0.619544  1.357572  0.462394  ... -0.010075 -0.066999 -0.498590
# ...         ...       ...       ...  ...       ...       ...       ...
# 63421 -7.553497  6.015618 -2.466143  ...  0.814710  0.918244 -0.715366
# 63634 -8.058012  6.442909 -2.412987  ...  0.816652  0.926157 -0.817706
# 64329 -8.350808  6.863604 -2.387567  ...  0.832398  0.931958 -0.874467
# 64411 -8.643193  7.284105 -2.362097  ...  0.847085  0.937416 -0.931178
# 64460 -8.935243  7.704449 -2.336584  ...  0.860912  0.942593 -0.987848
#
#             V23       V24       V25       V26       V27       V28  Amount
# 26268 -0.166172  0.085264  0.549844 -0.261117  0.012580  0.035939  108.00
# 45643  0.119613  0.369393  0.246145  0.091553 -0.017156  0.032557    0.89
# 50011  0.031323  0.489935  0.286082 -0.424303  0.057538  0.026498    1.18
# 51705  0.156970  0.039196  0.150016  0.123524 -0.005230  0.027740    1.29
# 55544 -0.116966 -1.082198 -0.033793  0.866450 -0.005089 -0.272605  121.30
# ...         ...       ...       ...       ...       ...       ...     ...
# 63421  0.210747 -0.060211  0.509535 -0.257284  1.170027  0.229301   99.99
# 63634 -0.150434 -0.039383  0.485640 -0.264325  1.159690  0.232758   99.99
# 64329 -0.192639 -0.035426  0.538665 -0.263934  1.134095  0.225973   99.99
# 64411 -0.235697 -0.031393  0.591558 -0.263516  1.108897  0.219021   99.99
# 64460 -0.279446 -0.027299  0.644344 -0.263078  1.084023  0.211933   99.99
#
# [661 rows x 30 columns]

# %%
print(Y)
# Out:
# 26268    0.0
# 45643    0.0
# 50011    0.0
# 51705    0.0
# 55544    0.0
#         ...
# 63421    1.0
# 63634    1.0
# 64329    1.0
# 64411    1.0
# 64460    1.0
# Name: Class, Length: 661, dtype: float64

# %% [markdown]
# split the data into Training Data & testing Data

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=2)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (661, 30) (528, 30) (133, 30)
